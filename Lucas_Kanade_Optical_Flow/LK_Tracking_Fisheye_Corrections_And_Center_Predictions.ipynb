# %% [markdown]
# # Lucas-Kanade Tracking Fisheye Correction Videos - Visual Checks
# Last edited: 12/08/2024
#
# By: Christina Wang

# %%
from google.colab import drive
drive.mount('/content/drive')

# ## next time, load it into your work folder:
# ## dont forget to restart the runtime, so it forgets about the old version !
# !cp "/content/drive/My Drive/NASA/cv2_cuda_test/cv2.cpython-310-x86_64-linux-gnu.so" .


# %cd /content/drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %% [markdown]
# #### Check GPU enabled

# %%
import cv2
count = cv2.cuda.getCudaEnabledDeviceCount()
print(count)
# Out:
# 1

# %% [markdown]
# If not 1, then switch hostruntime environment to GPU environment, or if already on GPU environment, may need to restart session to take effect

# %% [markdown]
# ## Functions to Conduct Lucas-Kanade Tracking

# %% [markdown]
# ### Non-Corrected Tracking

# %%
import numpy as np
import cv2 as cv
import pandas as pd

WIDTH_OFFSET = 90 # in pixels
HEIGHT_OFFSET = 20 # in pixels

def optical_flow_uncorrected(video_path, start_time, end_time, center_width, center_height, output_path, min_track_percent=100):
    cap = cv.VideoCapture(video_path)
    fps = cap.get(cv.CAP_PROP_FPS)
    #print('fps: ', fps)
    start_frame = int(start_time * fps)
    end_frame = int(end_time * fps)
    total_frames = end_frame - start_frame
    print('total_frames: ', total_frames)

    #feature_params = dict(maxCorners=1000, qualityLevel=0.3, minDistance=7, blockSize=7)
    feature_params = dict(maxCorners=1000, qualityLevel=0.01, minDistance=7, blockSize=12)
    #lk_params = dict(winSize=(15, 15), maxLevel=2, criteria=(cv.TERM_CRITERIA_EPS | cv.TERM_CRITERIA_COUNT, 10, 0.03))
    #lk_params = dict(winSize=(12, 12), maxLevel=3, criteria=(cv.TERM_CRITERIA_EPS | cv.TERM_CRITERIA_COUNT, 10, 0.0001))
    lk_params = dict(winSize=(12, 12), maxLevel=3)
    #color = np.random.randint(0, 255, (2073600, 3))
    #color = np.random.randint(0, 255, (100, 3))
    single_color = np.array([[15, 82, 186]])


    cap.set(cv.CAP_PROP_POS_FRAMES, start_frame)
    ret, old_frame = cap.read()
    old_gray = cv.cvtColor(old_frame, cv.COLOR_BGR2GRAY)

    # Start coordinate, here (5, 5)
    # represents the top left corner of rectangle
    #start_point = (660+WIDTH_OFFSET, 240 + HEIGHT_OFFSET) # (w, h) (1920, 1080)
    start_point = (600+WIDTH_OFFSET, 200 + HEIGHT_OFFSET) # (w, h) (1920, 1080)
    start_point = (400, 75)

    # Ending coordinate, here (, 220)
    # represents the bottom right corner of rectangle
    #end_point = (1260 + WIDTH_OFFSET, 840 + HEIGHT_OFFSET)
    end_point = (1250 + WIDTH_OFFSET, 900 + HEIGHT_OFFSET)
    end_point = (1520, 1060)

    center_region = (slice(start_point[1], end_point[1]), slice(start_point[0], end_point[0]))

    # h, w = old_gray.shape
    # center_x, center_y = w // 2, h // 2
    # half_width, half_height = center_width // 2, center_height // 2
    # center_region = (slice(center_y - half_height, center_y + half_height), slice(center_x - half_width, center_x + half_width))
    old_gray = old_gray[center_region]
    h_crop, w_crop = old_gray.shape
    p0 = cv.goodFeaturesToTrack(old_gray, mask=None, **feature_params)

    # if p0 is not None:
    #     p0[:, :, 0] += center_x - half_width
    #     p0[:, :, 1] += center_y - half_height

    mask = np.zeros_like(old_frame[center_region])
    color_tracks = {}
    distance_tracker = {}

    fourcc = cv.VideoWriter_fourcc(*'XVID')
    out = cv.VideoWriter(output_path, fourcc, fps, (w_crop, h_crop))

    while True:
        ret, frame = cap.read()
        if not ret or cap.get(cv.CAP_PROP_POS_FRAMES) > end_frame:
            print('No frames grabbed!')
            break


        frame = frame[center_region]

        frame_gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
        p1, st, err = cv.calcOpticalFlowPyrLK(old_gray, frame_gray, p0, None, **lk_params)

        if p1 is not None:
            good_new = p1[st == 1]
            good_old = p0[st == 1]

            for i, (new, old) in enumerate(zip(good_new, good_old)):
                a, b = new.ravel()
                c, d = old.ravel()
                point_id = tuple(map(int, old.ravel())) # store original point location

                distance = np.sqrt((a - c) ** 2 + (b - d) ** 2)

                # mask = cv.line(mask, (int(a), int(b)), (int(c), int(d)), color[i % 100].tolist(), 2)
                # frame = cv.circle(frame, (int(a), int(b)), 5, color[i % 100].tolist(), -1)
                # color_used = tuple(color[i % 100].tolist())
                # 2073600
                # mask = cv.line(mask, (int(a), int(b)), (int(c), int(d)), color[i % 2073600].tolist(), 2)
                # frame = cv.circle(frame, (int(a), int(b)), 5, color[i % 2073600].tolist(), -1)
                # color_used = tuple(color[i % 2073600].tolist())
                mask = cv.line(mask, (int(a), int(b)), (int(c), int(d)), single_color[0].tolist(), 2)
                frame = cv.circle(frame, (int(a), int(b)), 5, single_color[0].tolist(), -1)
                color_used = tuple(single_color[0].tolist())

                if color_used not in color_tracks:
                  color_tracks[color_used] = [(int(a), int(b)), (int(c), int(d))]
                  distance_tracker[color_used] = distance
                else:
                  color_tracks[color_used].append((int(c), int(d)))
                  distance_tracker[color_used] += distance

            img = cv.add(frame, mask)
            out.write(img)

        old_gray = frame_gray.copy()
        p0 = good_new.reshape(-1, 1, 2)

    cap.release()
    out.release()

    color_tracks_df = pd.DataFrame(list(color_tracks.items()), columns=['Color', 'Pixel_Positions'])
    color_tracks_df['Track_Length_Frame_Count'] = color_tracks_df['Pixel_Positions'].apply(len)
    color_tracks_df['Track_Percent'] = color_tracks_df['Track_Length_Frame_Count'] / total_frames * 100
    color_tracks_df = color_tracks_df[color_tracks_df['Track_Percent'] >= min_track_percent]

    distance_df = pd.DataFrame(list(distance_tracker.items()), columns=['Color', 'Connect_Dot_Distance'])
    color_tracks_df = pd.merge(color_tracks_df, distance_df, on='Color', how='left')
    color_tracks_df['Travel_Time_Seconds'] = color_tracks_df['Track_Length_Frame_Count'] / fps

    try:
      color_tracks_df['Total_Distance'] = color_tracks_df['Pixel_Positions'].apply(lambda x: np.sqrt((x[0][0] - x[-1][0]) ** 2 + (x[0][1] - x[-1][1]) ** 2))
      color_tracks_df['X_Distance'] = color_tracks_df['Pixel_Positions'].apply(lambda x: (x[-1][0] - x[0][0]))
      color_tracks_df['Y_Distance'] = color_tracks_df['Pixel_Positions'].apply(lambda x: (x[-1][1] - x[0][1]))
      color_tracks_df['Overall_Velocity'] = color_tracks_df['Total_Distance'] / color_tracks_df['Travel_Time_Seconds']
      color_tracks_df['X_Velocity'] = color_tracks_df['X_Distance'] / color_tracks_df['Travel_Time_Seconds']
      color_tracks_df['Y_Velocity'] = color_tracks_df['Y_Distance'] / color_tracks_df['Travel_Time_Seconds']
    except:
      print("none able to be tracked")

    return color_tracks_df

# Example usage:
# df = optical_flow('video.mp4', 10, 20, 12, 12, 'output.avi', min_track_percent=80)
# print(df)

# %% [markdown]
# ### Corrected Tracking

# %%
import numpy as np
import cv2 as cv
import pandas as pd

def undistort_fisheye_image(distorted_image):
    """
    Apply correction for fisheye distortion.
    Args:
        distorted_image (numpy.ndarray): original image that has the fisheye distortion.
     Returns:
        (numpy.ndarray): undistorted image with fisheye correction.
    """
    # Parameters provided
    f = 1.4  # focal length [mm]
    mu = 2.8e-3  # pixel pitch [mm]
    S = 2  # output (undistorted) image scale factor
    # distortion polynomial order:  [2 4 6 8]
    # polynomial coefficients:
    coeffs = np.array([0.01166363, -0.04819808, 0.07918044, -0.037572])

    H = distorted_image.shape[0]  # image height [pixel]
    W = distorted_image.shape[1]  # image width [pixel]
    cx = (W - 1) / 2  # image center coordinate [pixel]
    cy = (H - 1) / 2  # image center coordinate [pixel]

    K = np.array([[f / mu, 0, cx], [0, f / mu, cy], [0, 0, 1]])

    # compute intrinsic matrix for undistorted image
    cpx = (W * S - 1) / 2
    cpy = (H * S - 1) / 2
    P = np.array([[f / mu, 0, cpx], [0, f / mu, cpy], [0, 0, 1]])

    # rectification matrix (identity)
    R = np.eye(3)

    # produce undistorted image
    map1, map2 = cv.fisheye.initUndistortRectifyMap(K=K, D=coeffs, R=R, P=P, size=[W * S, H * S], m1type=cv.CV_16SC2)
    undistorted_image = cv.remap(distorted_image, map1, map2, interpolation=cv.INTER_LINEAR, borderMode=cv.BORDER_TRANSPARENT)
    return undistorted_image

#def crop_and_correct_image_cv(image, size1=(1500, 1500), offset=(85, 180), size2=(1000, 1000)):
def crop_and_correct_image_cv(image, size1=(1920, 1920), offset=(85, 180), size2=(1500, 1700)):

    h, w = image.shape[:2]
    print("undistorted image h, w:", h, w)

    # Cropping it to 1500X1500 and accounting for offset.
    center_h, center_w = h // 2, w // 2
    offset_h, offset_w = offset
    start_h = min(max(center_h - size1[0] // 2 + offset_h, 0), h - size1[0])
    start_w = min(max(center_w - size1[1] // 2 + offset_w, 0), w - size1[1])
    cropped_image = image[start_h:start_h + size1[0], start_w:start_w + size1[1]]
    h, w = cropped_image.shape[:2]

    # further crop the image to 1000X1000
    center_h, center_w = h // 2, w // 2
    start_h = max(center_h - size2[0] // 2, 0)
    start_w = max(center_w - size2[1] // 2, 0)

    return cropped_image[start_h:start_h + size2[0], start_w:start_w + size2[1]]



def optical_flow_corrected(video_path, start_time, end_time, center_width, center_height, output_path, min_track_percent=100):
    cap = cv.VideoCapture(video_path)
    fps = cap.get(cv.CAP_PROP_FPS)
    #print('fps: ', fps)
    start_frame = int(start_time * fps)
    end_frame = int(end_time * fps)
    total_frames = end_frame - start_frame
    print('total_frames: ', total_frames)

   #feature_params = dict(maxCorners=100, qualityLevel=0.3, minDistance=7, blockSize=7)
    #lk_params = dict(winSize=(15, 15), maxLevel=2, criteria=(cv.TERM_CRITERIA_EPS | cv.TERM_CRITERIA_COUNT, 10, 0.03))
    feature_params = dict(maxCorners=1000, qualityLevel=0.01, minDistance=7, blockSize=12)
    lk_params = dict(winSize=(12, 12), maxLevel=3, criteria=(cv.TERM_CRITERIA_EPS | cv.TERM_CRITERIA_COUNT, 10, 0.0001))
    # color = np.random.randint(0, 255, (100, 3))
    single_color = np.array([[15, 82, 186]])


    cap.set(cv.CAP_PROP_POS_FRAMES, start_frame)
    ret, old_frame = cap.read()
    #old_color_frame = cv.cvtColor(old_frame, cv.COLOR_BGR2RGB)
    old_color_frame = undistort_fisheye_image(old_frame)
    old_color_frame = crop_and_correct_image_cv(old_color_frame)
    old_gray = cv.cvtColor(old_color_frame, cv.COLOR_BGR2GRAY)

    #old_gray = cv.cvtColor(old_frame, cv.COLOR_BGR2GRAY)

    h, w = old_gray.shape
    #center_x, center_y = w // 2, h // 2
    #half_width, half_height = center_width // 2, center_height // 2
    #center_region = (slice(center_y - half_height, center_y + half_height), slice(center_x - half_width, center_x + half_width))
    #p0 = cv.goodFeaturesToTrack(old_gray[center_region], mask=None, **feature_params)
    p0 = cv.goodFeaturesToTrack(old_gray, mask=None, **feature_params)

    # if p0 is not None:
    #     p0[:, :, 0] += center_x - half_width
    #     p0[:, :, 1] += center_y - half_height

    mask = np.zeros_like(old_color_frame)
    color_tracks = {}
    distance_tracker = {}

    fourcc = cv.VideoWriter_fourcc(*'XVID')
    out = cv.VideoWriter(output_path, fourcc, fps, (w, h))

    while True:
        ret, frame = cap.read()
        if not ret or cap.get(cv.CAP_PROP_POS_FRAMES) > end_frame:
            print('No frames grabbed!')
            break

        #frame = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
        frame = undistort_fisheye_image(frame)
        frame = crop_and_correct_image_cv(frame)
        frame_gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)

        #frame_gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)

        p1, st, err = cv.calcOpticalFlowPyrLK(old_gray, frame_gray, p0, None, **lk_params)

        if p1 is not None:
            good_new = p1[st == 1]
            good_old = p0[st == 1]

            for i, (new, old) in enumerate(zip(good_new, good_old)):
                a, b = new.ravel()
                c, d = old.ravel()
                point_id = tuple(map(int, old.ravel())) # store original point location

                distance = np.sqrt((a - c) ** 2 + (b - d) ** 2)

                # mask = cv.line(mask, (int(a), int(b)), (int(c), int(d)), color[i % 100].tolist(), 2)
                # frame = cv.circle(frame, (int(a), int(b)), 5, color[i % 100].tolist(), -1)
                # color_used = tuple(color[i % 100].tolist())
                mask = cv.line(mask, (int(a), int(b)), (int(c), int(d)), single_color[0].tolist(), 2)
                frame = cv.circle(frame, (int(a), int(b)), 5, single_color[0].tolist(), -1)
                color_used = tuple(single_color[0].tolist())

                if color_used not in color_tracks:
                  color_tracks[color_used] = [(int(a), int(b)), (int(c), int(d))]
                  distance_tracker[color_used] = distance
                else:
                  color_tracks[color_used].append((int(c), int(d)))
                  distance_tracker[color_used] += distance

            img = cv.add(frame, mask)
            out.write(img)

        old_gray = frame_gray.copy()
        p0 = good_new.reshape(-1, 1, 2)

    cap.release()
    out.release()

    color_tracks_df = pd.DataFrame(list(color_tracks.items()), columns=['Color', 'Pixel_Positions'])
    color_tracks_df['Track_Length_Frame_Count'] = color_tracks_df['Pixel_Positions'].apply(len)
    color_tracks_df['Track_Percent'] = color_tracks_df['Track_Length_Frame_Count'] / total_frames * 100
    color_tracks_df = color_tracks_df[color_tracks_df['Track_Percent'] >= min_track_percent]

    distance_df = pd.DataFrame(list(distance_tracker.items()), columns=['Color', 'Connect_Dot_Distance'])
    color_tracks_df = pd.merge(color_tracks_df, distance_df, on='Color', how='left')
    color_tracks_df['Travel_Time_Seconds'] = color_tracks_df['Track_Length_Frame_Count'] / fps

    try:
      color_tracks_df['Total_Distance'] = color_tracks_df['Pixel_Positions'].apply(lambda x: np.sqrt((x[0][0] - x[-1][0]) ** 2 + (x[0][1] - x[-1][1]) ** 2))
      color_tracks_df['X_Distance'] = color_tracks_df['Pixel_Positions'].apply(lambda x: (x[-1][0] - x[0][0]))
      color_tracks_df['Y_Distance'] = color_tracks_df['Pixel_Positions'].apply(lambda x: (x[-1][1] - x[0][1]))
      color_tracks_df['Overall_Velocity'] = color_tracks_df['Total_Distance'] / color_tracks_df['Travel_Time_Seconds']
      color_tracks_df['X_Velocity'] = color_tracks_df['X_Distance'] / color_tracks_df['Travel_Time_Seconds']
      color_tracks_df['Y_Velocity'] = color_tracks_df['Y_Distance'] / color_tracks_df['Travel_Time_Seconds']
    except:
      print("none able to be tracked")

    return color_tracks_df

# Example usage:
# df = optical_flow('video.mp4', 10, 20, 12, 12, 'output.avi', min_track_percent=80)
# print(df)

# %%
def map_coordinates(coord, original_size=(1920, 1080), fisheye_params=None, crop_size1=(1500, 1500), crop_offset=(85, 180), crop_size2=(1000, 1000)):
    """
    Maps a coordinate from the original image to the undistorted image and the crop-corrected image.

    Args:
        coord (tuple): (x, y) coordinate in the original image.
        original_size (tuple): Size of the original image (width, height).
        fisheye_params (dict): Parameters for the fisheye undistortion.
        crop_size1 (tuple): Size of the first crop (width, height).
        crop_offset (tuple): Offset applied to the first crop.
        crop_size2 (tuple): Size of the second crop (width, height).

    Returns:
        dict: A dictionary with mappings to undistorted and crop-corrected coordinates.
    """
    x, y = coord

    # Map from original to undistorted image
    if fisheye_params:
        K = fisheye_params["K"]
        D = fisheye_params["D"]
        R = fisheye_params.get("R", np.eye(3))
        P = fisheye_params["P"]

        # Normalize coordinates to camera space
        coord_homog = np.array([x, y, 1.0], dtype=np.float32).reshape(-1, 1)
        undistorted_coord = cv2.fisheye.undistortPoints(
            coord_homog.T[:, :2].reshape(1, -1, 2),
            K=K, D=D, R=R, P=P
        )[0][0]
        x_undist, y_undist = undistorted_coord
    else:
        x_undist, y_undist = x, y

    # Map from undistorted to crop-corrected image (first crop)
    undist_h, undist_w = original_size[1] * 2, original_size[0] * 2  # Account for fisheye scaling
    center_h, center_w = undist_h // 2, undist_w // 2
    offset_h, offset_w = crop_offset

    # First crop coordinates
    start_h1 = max(center_h - crop_size1[1] // 2 + offset_h, 0)
    start_w1 = max(center_w - crop_size1[0] // 2 + offset_w, 0)
    x_cropped1 = x_undist - start_w1
    y_cropped1 = y_undist - start_h1

    # Map from first cropped image to final crop-corrected image
    crop1_h, crop1_w = crop_size1
    center_h1, center_w1 = crop1_h // 2, crop1_w // 2

    # Adjust for alignment to center (500, 500)
    start_h2 = center_h1 - crop_size2[1] // 2
    start_w2 = center_w1 - crop_size2[0] // 2
    x_cropped2 = x_cropped1 - start_w2
    y_cropped2 = y_cropped1 - start_h2

    # Return both mapped coordinates
    return {
        "undistorted": (x_undist, y_undist),
        "crop_corrected": (x_cropped2, y_cropped2)
    }

def map_coordinates2(coord, original_size=(1920, 1080), fisheye_params=None, crop_size1=(1500, 1500), crop_offset=(85, 180), crop_size2=(800, 800)):
    """
    Maps a coordinate from the original image to the undistorted image and the crop-corrected image.

    Args:
        coord (tuple): (x, y) coordinate in the original image.
        original_size (tuple): Size of the original image (width, height).
        fisheye_params (dict): Parameters for the fisheye undistortion.
        crop_size1 (tuple): Size of the first crop (width, height).
        crop_offset (tuple): Offset applied to the first crop.
        crop_size2 (tuple): Size of the second crop (width, height).

    Returns:
        dict: A dictionary with mappings to undistorted and crop-corrected coordinates.
    """
    x, y = coord

    # Step 1: Map from original to undistorted image
    if fisheye_params:
        K = fisheye_params["K"]
        D = fisheye_params["D"]
        R = fisheye_params.get("R", np.eye(3))
        P = fisheye_params["P"]

        # Normalize coordinates to camera space
        coord_homog = np.array([x, y, 1.0], dtype=np.float32).reshape(-1, 1)
        undistorted_coord = cv2.fisheye.undistortPoints(
            coord_homog.T[:, :2].reshape(1, -1, 2),
            K=K, D=D, R=R, P=P
        )[0][0]
        x_undist, y_undist = undistorted_coord
    else:
        x_undist, y_undist = x, y  # No undistortion applied

    # Step 2: Map from undistorted to first cropped image
    undist_h, undist_w = original_size[1] * 2, original_size[0] * 2  # Account for fisheye scaling
    center_h, center_w = undist_h // 2, undist_w // 2
    offset_h, offset_w = crop_offset

    # First crop starting points
    start_h1 = max(center_h - crop_size1[1] // 2 + offset_h, 0)
    start_w1 = max(center_w - crop_size1[0] // 2 + offset_w, 0)
    x_cropped1 = x_undist - start_w1
    y_cropped1 = y_undist - start_h1

    # Step 3: Map from first cropped image to final crop-corrected image
    center_h_crop = center_h - start_h1  # Adjusted center in the first cropped image
    center_w_crop = center_w - start_w1

    # Adjust coordinates for final cropping stage
    start_h2 = max(center_h_crop - crop_size2[1] // 2, 0)
    start_w2 = max(center_w_crop - crop_size2[0] // 2, 0)
    x_cropped2 = x_cropped1 - start_w2
    y_cropped2 = y_cropped1 - start_h2

    # Return the coordinates for both stages
    return {
        "undistorted": (x_undist, y_undist),
        "crop_corrected": (x_cropped2, y_cropped2)
    }

def unmap_coordinates2(crop_corrected_coord, original_size=(1920, 1080), fisheye_params=None,
                       crop_size1=(1500, 1500), crop_offset=(85, 180), crop_size2=(800, 800)):
    """
    Reverses the mapping from crop-corrected coordinates to the undistorted and original image coordinates.

    Args:
        crop_corrected_coord (tuple): (x, y) coordinate in the crop-corrected image.
        original_size (tuple): Size of the original image (width, height).
        fisheye_params (dict): Parameters for the fisheye distortion.
        crop_size1 (tuple): Size of the first crop (width, height).
        crop_offset (tuple): Offset applied to the first crop.
        crop_size2 (tuple): Size of the second crop (width, height).

    Returns:
        dict: A dictionary with mappings to undistorted and original coordinates.
    """
    x_cropped2, y_cropped2 = crop_corrected_coord

    # Step 1: Reconstruct the undistorted coordinates
    undist_h, undist_w = original_size[1] * 2, original_size[0] * 2  # Account for fisheye scaling
    center_h, center_w = undist_h // 2, undist_w // 2
    offset_h, offset_w = crop_offset

    # First crop starting points
    start_h1 = max(center_h - crop_size1[1] // 2 + offset_h, 0)
    start_w1 = max(center_w - crop_size1[0] // 2 + offset_w, 0)

    # Adjusted center in the first cropped image
    center_h_crop = center_h - start_h1
    center_w_crop = center_w - start_w1

    # Second crop starting points
    start_h2 = max(center_h_crop - crop_size2[1] // 2, 0)
    start_w2 = max(center_w_crop - crop_size2[0] // 2, 0)

    # Reconstruct undistorted coordinates
    x_cropped1 = x_cropped2 + start_w2
    y_cropped1 = y_cropped2 + start_h2
    x_undist = x_cropped1 + start_w1
    y_undist = y_cropped1 + start_h1

    # Step 2: Adjust undistorted coordinates to match the original camera matrix
    if fisheye_params:
        K = fisheye_params["K"]
        D = fisheye_params["D"]
        P = fisheye_params["P"]

        # Compute the offset between the principal points of K and P
        cx_offset = P[0, 2] - K[0, 2]
        cy_offset = P[1, 2] - K[1, 2]

        # Adjust the undistorted coordinates
        x_undist_adjusted = x_undist - cx_offset
        y_undist_adjusted = y_undist - cy_offset

        # Normalize the adjusted undistorted coordinates
        x_norm_undist = (x_undist_adjusted - K[0, 2]) / K[0, 0]
        y_norm_undist = (y_undist_adjusted - K[1, 2]) / K[1, 1]

        # Prepare undistorted normalized coordinates
        undistorted_points = np.array([[[x_norm_undist, y_norm_undist]]], dtype=np.float64)

        # Apply fisheye distortion to get normalized distorted coordinates
        distorted_points = cv2.fisheye.distortPoints(
            undistorted_points,
            K=np.eye(3),
            D=D
        )

        # Map normalized distorted coordinates back to pixel coordinates using K
        x_distorted = distorted_points[0, 0, 0] * K[0, 0] + K[0, 2]
        y_distorted = distorted_points[0, 0, 1] * K[1, 1] + K[1, 2]
        x, y = x_distorted, y_distorted
    else:
        x, y = x_undist, y_undist  # No distortion applied

    # Return the coordinates for both stages
    return {
        "undistorted": (x_undist, y_undist),
        "original": (x, y)
    }

# %% [markdown]
# ## Functions to get cropped video frames without LK Tracking for comparison

# %% [markdown]
# ### Un-Corrected Frames

# %%
import numpy as np
import cv2 as cv
import pandas as pd

WIDTH_OFFSET = 90 # in pixels
HEIGHT_OFFSET = 20 # in pixels

def get_plain_video_uncorrected(video_path, start_time, end_time, center_width, center_height, output_path):
    cap = cv.VideoCapture(video_path)
    fps = cap.get(cv.CAP_PROP_FPS)
    #print('fps: ', fps)
    start_frame = int(start_time * fps)
    end_frame = int(end_time * fps)
    total_frames = end_frame - start_frame
    print('total_frames: ', total_frames)

    cap.set(cv.CAP_PROP_POS_FRAMES, start_frame)
    ret, old_frame = cap.read()
    old_gray = cv.cvtColor(old_frame, cv.COLOR_BGR2GRAY)

    # Start coordinate, here (5, 5)
    # represents the top left corner of rectangle
    #start_point = (660+WIDTH_OFFSET, 240 + HEIGHT_OFFSET) # (w, h) (1920, 1080)
    start_point = (600+WIDTH_OFFSET, 200 + HEIGHT_OFFSET) # (w, h) (1920, 1080)
    if center_width == 1920:
      start_point = (0, 0)


    # Ending coordinate, here (, 220)
    # represents the bottom right corner of rectangle
    #end_point = (1260 + WIDTH_OFFSET, 840 + HEIGHT_OFFSET)
    end_point = (1250 + WIDTH_OFFSET, 900 + HEIGHT_OFFSET)
    if center_height == 1080:
      end_point = (1920, 1080)
    center_region = (slice(start_point[1], end_point[1]), slice(start_point[0], end_point[0]))

    # h, w = old_gray.shape
    # center_x, center_y = w // 2, h // 2
    # half_width, half_height = center_width // 2, center_height // 2
    # center_region = (slice(center_y - half_height, center_y + half_height), slice(center_x - half_width, center_x + half_width))
    old_gray = old_gray[center_region]
    h_crop, w_crop = old_gray.shape


    mask = np.zeros_like(old_frame[center_region])

    fourcc = cv.VideoWriter_fourcc(*'XVID')
    out = cv.VideoWriter(output_path, fourcc, fps, (w_crop, h_crop))

    while True:
        ret, frame = cap.read()
        if not ret or cap.get(cv.CAP_PROP_POS_FRAMES) > end_frame:
            print('No frames grabbed!')
            break

        frame = frame[center_region]

        img = cv.add(frame, mask)
        out.write(img)

    cap.release()
    out.release()

# Example usage:
# df = optical_flow('video.mp4', 10, 20, 12, 12, 'output.avi', min_track_percent=80)
# print(df)

# %% [markdown]
# ### Corrected Frames

# %%
def get_plain_video_corrected(video_path, start_time, end_time, center_width, center_height, output_path):
    cap = cv.VideoCapture(video_path)
    fps = cap.get(cv.CAP_PROP_FPS)
    #print('fps: ', fps)
    start_frame = int(start_time * fps)
    end_frame = int(end_time * fps)
    total_frames = end_frame - start_frame
    print('total_frames: ', total_frames)


    cap.set(cv.CAP_PROP_POS_FRAMES, start_frame)
    ret, old_frame = cap.read()
    #old_color_frame = cv.cvtColor(old_frame, cv.COLOR_BGR2RGB)
    old_color_frame = undistort_fisheye_image(old_frame)
    old_color_frame = crop_and_correct_image_cv(old_color_frame)
    old_gray = cv.cvtColor(old_color_frame, cv.COLOR_BGR2GRAY)

    #old_gray = cv.cvtColor(old_frame, cv.COLOR_BGR2GRAY)

    h, w = old_gray.shape

    mask = np.zeros_like(old_color_frame)


    fourcc = cv.VideoWriter_fourcc(*'XVID')
    out = cv.VideoWriter(output_path, fourcc, fps, (w, h))

    while True:
        ret, frame = cap.read()
        if not ret or cap.get(cv.CAP_PROP_POS_FRAMES) > end_frame:
            print('No frames grabbed!')
            break

        frame = undistort_fisheye_image(frame)
        frame = crop_and_correct_image_cv(frame)
        frame_gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)

        img = cv.add(frame, mask)
        out.write(img)

        old_gray = frame_gray.copy()

    cap.release()
    out.release()

# %% [markdown]
# ## Get Uncropped Video Trimmed to Duration of Interest

# %%
import numpy as np
import cv2 as cv
import pandas as pd

WIDTH_OFFSET = 50 # in pixels
HEIGHT_OFFSET = 40 # in pixels

def get_plain_video_uncropped(video_path, start_time, end_time, output_path):
    cap = cv.VideoCapture(video_path)
    fps = cap.get(cv.CAP_PROP_FPS)
    #print('fps: ', fps)
    start_frame = int(start_time * fps)
    end_frame = int(end_time * fps)
    total_frames = end_frame - start_frame
    print('total_frames: ', total_frames)

    cap.set(cv.CAP_PROP_POS_FRAMES, start_frame)
    ret, old_frame = cap.read()
    old_gray = cv.cvtColor(old_frame, cv.COLOR_BGR2GRAY)
    h, w = old_gray.shape



    mask = np.zeros_like(old_frame)

    fourcc = cv.VideoWriter_fourcc(*'XVID')
    out = cv.VideoWriter(output_path, fourcc, fps, (w, h))

    while True:
        ret, frame = cap.read()
        if not ret or cap.get(cv.CAP_PROP_POS_FRAMES) > end_frame:
            print('No frames grabbed!')
            break

        img = cv.add(frame, mask)
        out.write(img)

    cap.release()
    out.release()

# Example usage:
# df = optical_flow('video.mp4', 10, 20, 12, 12, 'output.avi', min_track_percent=80)
# print(df)

# %% [markdown]
# ## Call Above Functions For Visual Comparisons of 10 Second Snippet of Test Dataset Video

# %% [markdown]
# Get the LK tracking on original non-fisheye corrected video.

# %%
#df = optical_flow('/content/drive/MyDrive/NASA/input_videos/full_videos/170418_175706_183328.avi', 10, 20, 630, 720, '/content/drive/MyDrive/NASA/output/cloud_output_non_fisheye_LK_sanity.mp4')
#df = optical_flow_uncorrected('/content/drive/MyDrive/NASA/input_videos/full_videos/170418_175706_183328.avi', 10, 20, 1080, 1920, '/content/drive/MyDrive/NASA/output/full_cloud_output_uncorrected_LK_tracking.mp4')

# %% [markdown]
# Get raw frames, no tracking at same cropped area.

# %%
#get_plain_video('/content/drive/MyDrive/NASA/input_videos/full_videos/170418_175706_183328.avi', 10, 20, 630, 720, '/content/drive/MyDrive/NASA/output/cloud_output_non_corrected_plain_LK.mp4')
#get_plain_video_uncorrected('/content/drive/MyDrive/NASA/input_videos/full_videos/170418_175706_183328.avi', 10, 20, 1080, 1920, '/content/drive/MyDrive/NASA/output/full_cloud_output_uncorrected_plain.mp4')

# %% [markdown]
# Get LK Tracking on corrected video

# %%
optical_flow_corrected('/content/drive/MyDrive/NASA/input_videos/full_videos/170418_175706_183328.avi', 10, 20, 1080, 1920, '/content/drive/MyDrive/NASA/output/full_cloud_output_corrected_LK_tracking.mp4')
# Out:
# total_frames:  600
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# undistorted image h, w: 2160 3840
# No frames grabbed!
#            Color                                    Pixel_Positions  \
# 0  (15, 82, 186)  [(1024, 513), (1025, 513), (907, 504), (676, 2...
#
#    Track_Length_Frame_Count  Track_Percent  Connect_Dot_Distance  \
# 0                    595219   99203.166667         490985.154351
#
#    Travel_Time_Seconds  Total_Distance  X_Distance  Y_Distance  \
# 0          9920.316667      492.978701         172         462
#
#    Overall_Velocity  X_Velocity  Y_Velocity
# 0          0.049694    0.017338    0.046571

# %% [markdown]
# Get raw frames, corrected, at same cropped area

# %%
get_plain_video_corrected('/content/drive/MyDrive/NASA/input_videos/full_videos/170418_175706_183328.avi', 10, 20, 1080, 1920, '/content/drive/MyDrive/NASA/output/full_cloud_output_corrected_plain.mp4')
# Out:
# total_frames:  600
# No frames grabbed!

# %% [markdown]
# Get raw frames, uncropped, for perspective

# %%
get_plain_video_uncropped('/content/drive/MyDrive/NASA/input_videos/full_videos/170418_175706_183328.avi', 10, 20, '/content/drive/MyDrive/NASA/output/cloud_output_non_corrected_plain_uncropped_LK.mp4')
# Out:
# total_frames:  600
# No frames grabbed!

# %%
df.describe()
# Out:
#        Track_Length_Frame_Count  Track_Percent  Connect_Dot_Distance  \
# count                       1.0       1.000000              1.000000
# mean                   585611.0   97601.833333         129252.170745
# std                         NaN            NaN                   NaN
# min                    585611.0   97601.833333         129252.170745
# 25%                    585611.0   97601.833333         129252.170745
# 50%                    585611.0   97601.833333         129252.170745
# 75%                    585611.0   97601.833333         129252.170745
# max                    585611.0   97601.833333         129252.170745
#
#        Travel_Time_Seconds  Total_Distance  X_Distance  Y_Distance  \
# count             1.000000        1.000000         1.0         1.0
# mean           9760.183333      413.962559      -394.0      -127.0
# std                    NaN             NaN         NaN         NaN
# min            9760.183333      413.962559      -394.0      -127.0
# 25%            9760.183333      413.962559      -394.0      -127.0
# 50%            9760.183333      413.962559      -394.0      -127.0
# 75%            9760.183333      413.962559      -394.0      -127.0
# max            9760.183333      413.962559      -394.0      -127.0
#
#        Overall_Velocity  X_Velocity  Y_Velocity
# count          1.000000    1.000000    1.000000
# mean           0.042413   -0.040368   -0.013012
# std                 NaN         NaN         NaN
# min            0.042413   -0.040368   -0.013012
# 25%            0.042413   -0.040368   -0.013012
# 50%            0.042413   -0.040368   -0.013012
# 75%            0.042413   -0.040368   -0.013012
# max            0.042413   -0.040368   -0.013012

# %% [markdown]
# ## Calculate Cloud Heights for Trackable Center Pixels

# %% [markdown]
# ### Heights for First Frame In Selected 10 second snippet

# %%
import math

diam = 8
frame_pixels = 1080
f = 1.4
v = 202.7
h = 19970
pitch = 0.92

def get_height_helper(u, h, f, v, pitch):
    #print(u, h, f, v, pitch)
    height = (h - f*v/u)*math.cos(math.pi*pitch/180)
    #print('height: ', height)
    return(height)

def calculate_cloud_height(df, v, h, pitch, f=1.4, diam=8, frame_pixels=1080):
  """
  diam = Diameter of the camera frame
  frame_pixels = Pixels of the verticle diameter of the camera frame
  f = focal length of the camera
  v = Velocity of the plane in meters/second
  h = Height of the plane in meters
  """
  df['X_Velocity_Converted'] = df['X_Velocity'] * diam/frame_pixels
  df['Y_Velocity_Converted'] = df['Y_Velocity'] * diam/frame_pixels
  #df['Overall_Velocity_Converted'] = df['Overall_Velocity'] * diam/frame_pixels
  df['Height'] = df['Y_Velocity_Converted'].apply(lambda u: get_height_helper(u, h, f, v, pitch))

  return df

df = calculate_cloud_height(df, v, h, pitch)
df[['Height']]
# Out:
#          Height
# 0  2.963805e+06

# %%
print(df[['Height']].mean())
# Out:
# Height    2.963805e+06
# dtype: float64

# %% [markdown]
# ### Generic Calculate Cloud Heights for Trackable Center Pixels - Full Test Set Video

# %% [markdown]
# #### Set-up Azure Connections for BlobStorage

# %%
# !pip install tensorflow-io
# !pip install azure-storage-blob azure-identity
# Out:
# Requirement already satisfied: tensorflow-io in /usr/local/lib/python3.10/dist-packages (0.37.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.37.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-io) (0.37.1)
# Requirement already satisfied: azure-storage-blob in /usr/local/lib/python3.10/dist-packages (12.24.0)
# Requirement already satisfied: azure-identity in /usr/local/lib/python3.10/dist-packages (1.19.0)
# Requirement already satisfied: azure-core>=1.30.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (1.32.0)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (43.0.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (4.12.2)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (0.7.2)
# Requirement already satisfied: msal>=1.30.0 in /usr/local/lib/python3.10/dist-packages (from azure-identity) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from azure-identity) (1.2.0)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.30.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: portalocker<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from msal-extensions>=1.2.0->azure-identity) (2.10.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2024.8.30)

# %%
from azure.storage.blob import BlobServiceClient, BlobClient
import os
import tensorflow as tf
import tensorflow_io as tfio
import pandas as pd

ENV_GOOGLE_COLAB = 1

account_name = ""
account_key = ""
container_name = ""

if ENV_GOOGLE_COLAB:
    from google.colab import userdata

    account_name = userdata.get('storage_account_name')
    account_key = userdata.get('storage_account_key')
    container_name = userdata.get('blob_container_name')
else:
    import configparser

    config = configparser.ConfigParser()
    config.read('../config.ini')
    account_name = config['DEFAULT']['storage_account_name']
    account_key = config['DEFAULT']['storage_account_key']
    container_name = config['DEFAULT']['blob_container_name']

connection_string = f"DefaultEndpointsProtocol=https;AccountName={account_name};AccountKey={account_key};EndpointSuffix=core.windows.net"
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
container_client = blob_service_client.get_container_client(container_name)

# Colab Azure QuickStart Guide: https://colab.research.google.com/github/tensorflow/io/blob/master/docs/tutorials/azure.ipynb#scrollTo=Read_and_write_files_to_Azure_Storage_with_TensorFlow
os.environ['TF_AZURE_STORAGE_KEY'] = account_key
# Azure Storage Account Name

# list files and directories in storage container
#tf.io.gfile.listdir(f'az://{account_name}/{container_name}')

# %% [markdown]
# #### Get Truth Dataset from Azure Blob Storage

# %%
blobpath = "60fps_v1/20170418/full_df.csv"
client = BlobClient.from_connection_string(connection_string, container_name, blobpath)
blob = client.download_blob()
full_df = pd.read_csv(blob)

# %%
full_df['DateTime_UTC'] = pd.to_datetime(full_df['DateTime_UTC'], infer_datetime_format=True)
truth_df = full_df[full_df['top_height'].notna()]
print("size_before", truth_df.shape)
truth_df = truth_df.loc[truth_df.groupby('timestamp_y')['DateTime_UTC'].idxmin()] # take first frame aggregated at seconds level (not millisecond resolution)
print("size_after", truth_df.shape)
truth_frames = truth_df.frame_num
truth_df.head()
# Out:
# size_before (25864, 52)
# size_after (432, 52)
# <ipython-input-15-17ea30693ca5>:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   full_df['DateTime_UTC'] = pd.to_datetime(full_df['DateTime_UTC'], infer_datetime_format=True)
#       Unnamed: 0                 frames_filename  frame_num      Date    Time  \
# 180          180   20170418_175709_frame_180.jpg        180  20170418  175709
# 480          480   20170418_175714_frame_480.jpg        480  20170418  175714
# 780          780   20170418_175719_frame_780.jpg        780  20170418  175719
# 1080        1080  20170418_175724_frame_1080.jpg       1080  20170418  175724
# 1380        1380  20170418_175729_frame_1380.jpg       1380  20170418  175729
#
#                  DateTime Short_Name            DateTime_UTC        Lat  \
# 180   2017-04-18 17:57:09       IWG1 2017-04-18 17:57:09.004  34.610995
# 480   2017-04-18 17:57:14       IWG1 2017-04-18 17:57:14.004  34.620100
# 780   2017-04-18 17:57:19       IWG1 2017-04-18 17:57:19.004  34.629211
# 1080  2017-04-18 17:57:24       IWG1 2017-04-18 17:57:24.004  34.638317
# 1380  2017-04-18 17:57:29       IWG1 2017-04-18 17:57:29.004  34.647425
#
#             Lon  ...      lat      lon      alt  angle    N     GH  \
# 180  -86.583988  ...  34.6076 -86.5841  19966.0   1.05  2.0 -999.0
# 480  -86.583985  ...  34.6167 -86.5841  19966.0   1.12  2.0 -999.0
# 780  -86.583980  ...  34.6258 -86.5841  19966.0   1.12  4.0  210.0
# 1080 -86.583978  ...  34.6349 -86.5841  19966.0   1.10  3.0  210.0
# 1380 -86.583978  ...  34.6440 -86.5841  19966.0   1.19  2.0  210.0
#
#       top_height  bottom_height  layer_discriminator  angle_diff_to_prev
# 180      13161.0         9953.0                  3.0               -0.04
# 480      13131.0        10013.0                  3.0                0.07
# 780      13161.0         9833.0                  3.0                0.00
# 1080     13191.0         9923.0                  3.0               -0.02
# 1380     13161.0        10133.0                  3.0                0.09
#
# [5 rows x 52 columns]

# %%
full_df.columns
# Out:
# Index(['Unnamed: 0', 'frames_filename', 'frame_num', 'Date', 'Time',
#        'DateTime', 'Short_Name', 'DateTime_UTC', 'Lat', 'Lon', 'GPS_MSL_Alt',
#        'WGS_84_Alt', 'Press_Alt', 'Radar_Alt', 'Grnd_Spd', 'True_Airspeed',
#        'Indicated_Airspeed', 'Mach_Number', 'Vert_Velocity', 'True_Hdg',
#        'Track', 'Drift', 'Pitch', 'Roll', 'Side_slip', 'Angle_of_Attack',
#        'Ambient_Temp', 'Dew_Point', 'Total_Temp', 'Static_Press',
#        'Dynamic_Press', 'Cabin_Pressure', 'Wind_Speed', 'Wind_Dir',
#        'Vert_Wind_Spd', 'Solar_Zenith', 'Sun_Elev_AC', 'Sun_Az_Grd',
#        'Sun_Az_AC', 'timestamp_x', 'date', 'timestamp_y', 'lat', 'lon', 'alt',
#        'angle', 'N', 'GH', 'top_height', 'bottom_height',
#        'layer_discriminator', 'angle_diff_to_prev'],
#       dtype='object')

# %%
first_frame_time = full_df[full_df['frame_num'] == 1]['DateTime_UTC'].iloc[0]

truth_df['time_since_first_frame'] = pd.Series(truth_df['DateTime_UTC'] - first_frame_time).dt.total_seconds()

truth_df[['time_since_first_frame']].head()
# Out:
#       time_since_first_frame
# 180                      3.0
# 480                      8.0
# 780                     13.0
# 1080                    18.0
# 1380                    23.0

# %%
truth_df.shape
# Out:
# (432, 53)

# %%
truth_df.tail()
# Out:
#         Unnamed: 0                   frames_filename  frame_num      Date  \
# 129840      129840  20170418_183310_frame_129840.jpg     129840  20170418
# 130140      130140  20170418_183315_frame_130140.jpg     130140  20170418
# 130440      130440  20170418_183320_frame_130440.jpg     130440  20170418
# 130740      130740  20170418_183325_frame_130740.jpg     130740  20170418
# 131040      131040  20170418_183330_frame_131040.jpg     131040  20170418
#
#           Time             DateTime Short_Name            DateTime_UTC  \
# 129840  183310  2017-04-18 18:33:10       IWG1 2017-04-18 18:33:10.004
# 130140  183315  2017-04-18 18:33:15       IWG1 2017-04-18 18:33:15.004
# 130440  183320  2017-04-18 18:33:20       IWG1 2017-04-18 18:33:20.004
# 130740  183325  2017-04-18 18:33:25       IWG1 2017-04-18 18:33:25.004
# 131040  183330  2017-04-18 18:33:30       IWG1 2017-04-18 18:33:30.004
#
#               Lat        Lon  ...      lon      alt  angle    N     GH  \
# 129840  33.709382 -86.257035  ... -86.2552  19966.0   0.74  2.0  180.0
# 130140  33.708933 -86.267760  ... -86.2661  19966.0   0.75  2.0  210.0
# 130440  33.708490 -86.278821  ... -86.2770  19966.0   0.74  3.0  240.0
# 130740  33.708039 -86.289877  ... -86.2879  19966.0   0.75  4.0  240.0
# 131040  33.707594 -86.300582  ... -86.2989  19966.0   0.74  2.0  240.0
#
#         top_height  bottom_height  layer_discriminator  angle_diff_to_prev  \
# 129840     11962.0        10823.0                  3.0               -0.05
# 130140     12022.0        10943.0                  3.0                0.01
# 130440     12082.0        10913.0                  3.0               -0.01
# 130740     12052.0        10883.0                  3.0                0.01
# 131040     12082.0        10853.0                  3.0               -0.01
#
#         time_since_first_frame
# 129840                  2164.0
# 130140                  2169.0
# 130440                  2174.0
# 130740                  2179.0
# 131040                  2184.0
#
# [5 rows x 53 columns]

# %% [markdown]
# #### Get Truth Dataset from Yash's Dataset

# %%
test_df = pd.read_csv("NASA/yash_datasets/train_dataset.csv")
test_df = test_df.dropna()
test_df.head()
# Out:
#                timestamp                                         image_path  \
# 180  2017-04-18 17:57:09  60fps_v1/20170418/170418_175706_183328_frames/...
# 181  2017-04-18 17:57:09  60fps_v1/20170418/170418_175706_183328_frames/...
# 182  2017-04-18 17:57:09  60fps_v1/20170418/170418_175706_183328_frames/...
# 183  2017-04-18 17:57:09  60fps_v1/20170418/170418_175706_183328_frames/...
# 184  2017-04-18 17:57:09  60fps_v1/20170418/170418_175706_183328_frames/...
#
#            Lat        Lon  GPS_MSL_Alt  WGS_84_Alt  Press_Alt  Grnd_Spd  \
# 180  34.610995 -86.583988      19969.6     19969.8    65045.0     202.8
# 181  34.610995 -86.583988      19969.6     19969.8    65045.0     202.8
# 182  34.610995 -86.583988      19969.6     19969.8    65045.0     202.8
# 183  34.610995 -86.583988      19969.6     19969.8    65045.0     202.8
# 184  34.610995 -86.583988      19969.6     19969.8    65045.0     202.8
#
#      True_Airspeed  Mach_Number  ...  Wind_Speed  Wind_Dir  Solar_Zenith  \
# 180          201.0        0.692  ...         3.7     236.4          23.7
# 181          201.0        0.692  ...         3.7     236.4          23.7
# 182          201.0        0.692  ...         3.7     236.4          23.7
# 183          201.0        0.692  ...         3.7     236.4          23.7
# 184          201.0        0.692  ...         3.7     236.4          23.7
#
#      Sun_Elev_AC  Sun_Az_Grd  Sun_Az_AC  hour_of_day  day_of_year  \
# 180         67.3      -173.6     -172.5        17.95          108
# 181         67.3      -173.6     -172.5        17.95          108
# 182         67.3      -173.6     -172.5        17.95          108
# 183         67.3      -173.6     -172.5        17.95          108
# 184         67.3      -173.6     -172.5        17.95          108
#
#      validation_height  sequence_length
# 180            13161.0              181
# 181            13161.0                1
# 182            13161.0                1
# 183            13161.0                1
# 184            13161.0                1
#
# [5 rows x 31 columns]

# %%
test_df.columns
# Out:
# Index(['timestamp', 'image_path', 'Lat', 'Lon', 'GPS_MSL_Alt', 'WGS_84_Alt',
#        'Press_Alt', 'Grnd_Spd', 'True_Airspeed', 'Mach_Number',
#        'Vert_Velocity', 'True_Hdg', 'Track', 'Drift', 'Pitch', 'Roll',
#        'Ambient_Temp', 'Total_Temp', 'Static_Press', 'Dynamic_Press',
#        'Cabin_Pressure', 'Wind_Speed', 'Wind_Dir', 'Solar_Zenith',
#        'Sun_Elev_AC', 'Sun_Az_Grd', 'Sun_Az_AC', 'hour_of_day', 'day_of_year',
#        'validation_height', 'sequence_length'],
#       dtype='object')

# %%
# prompt: Can you make the index into a frame_number column and get the first frame_number per timestamp? Do this for the test_df dataframe

# Assuming 'test_df' is already defined as in your provided code.
# Make a copy to avoid modifying the original DataFrame
test_df_copy = test_df.copy()

# Convert the index to a column named 'frame_number'
test_df_copy = test_df_copy.reset_index()
test_df_copy = test_df_copy.rename(columns={'index': 'frame_num'})

# Assuming 'timestamp' is a column in your DataFrame
# Group by 'timestamp' and get the first 'frame_number' for each timestamp
first_frames_per_timestamp = test_df_copy.loc[test_df_copy.groupby('timestamp')['frame_num'].idxmin()]
print(first_frames_per_timestamp.shape)

first_frames_per_timestamp.head()
# Out:
# (432, 32)
#      frame_num            timestamp  \
# 0          180  2017-04-18 17:57:09
# 60         480  2017-04-18 17:57:14
# 120        780  2017-04-18 17:57:19
# 180       1080  2017-04-18 17:57:24
# 240       1380  2017-04-18 17:57:29
#
#                                             image_path        Lat        Lon  \
# 0    60fps_v1/20170418/170418_175706_183328_frames/...  34.610995 -86.583988
# 60   60fps_v1/20170418/170418_175706_183328_frames/...  34.620100 -86.583985
# 120  60fps_v1/20170418/170418_175706_183328_frames/...  34.629211 -86.583980
# 180  60fps_v1/20170418/170418_175706_183328_frames/...  34.638317 -86.583978
# 240  60fps_v1/20170418/170418_175706_183328_frames/...  34.647425 -86.583978
#
#      GPS_MSL_Alt  WGS_84_Alt  Press_Alt  Grnd_Spd  True_Airspeed  ...  \
# 0        19969.6     19969.8    65045.0     202.8          201.0  ...
# 60       19968.1     19968.3    65032.5     202.8          201.0  ...
# 120      19967.6     19967.6    65032.5     202.8          201.0  ...
# 180      19967.1     19967.2    65035.0     202.8          200.2  ...
# 240      19966.6     19966.6    65027.5     202.8          200.8  ...
#
#      Wind_Speed  Wind_Dir  Solar_Zenith  Sun_Elev_AC  Sun_Az_Grd  Sun_Az_AC  \
# 0           3.7     236.4          23.7         67.3      -173.6     -172.5
# 60          3.5     236.3          23.7         67.4      -173.6     -172.4
# 120         3.6     237.2          23.7         67.4      -173.5     -172.5
# 180         4.0     231.4          23.7         67.4      -173.5     -172.5
# 240         3.9     231.8          23.7         67.4      -173.4     -172.5
#
#      hour_of_day  day_of_year  validation_height  sequence_length
# 0          17.95          108            13161.0              181
# 60         17.95          108            13131.0              241
# 120        17.95          108            13161.0              241
# 180        17.95          108            13191.0              241
# 240        17.95          108            13161.0              241
#
# [5 rows x 32 columns]

# %%
#truth_df = first_frames_per_timestamp.copy()

# %% [markdown]
# #### Get Average Height of Trackable Pixles in Center of Test Dataset Video Frames

# %%
## read previous run

# results_df = pd.read_csv('/content/drive/MyDrive/NASA/output/dataframes/20241027_051119_LK_output.csv')
# print(results_df.shape)
# results_df.head()

# %%
# result.tail()

# %% [markdown]
# ## Redefine Optical_flow version for center 48 x 48 pixel tracking

# %%
diam = 7.6
frame_pixels = 1082
mu = 7.6/1082
f = 1.4
mu_1 = 2.8e-3
S = 2

def get_undistorted_endpoints(x, y, H, W, mu=mu, S=2):
    cx = (W-1)/2        # image center coordinate [pixel]
    cy = (H-1)/2        # image center coordinate [pixel]

    K = np.array([[f/mu,0,cx],[0,f/mu,cy],[0,0,1]])

    # compute intrinsic matrix for ouput image
    cpx = (W*S-1)/2
    cpy = (H*S-1)/2
    P = np.array([[f/mu,0,cpx],[0,f/mu,cpy],[0,0,1]])

    D = np.array([0.01166363, -0.04819808, 0.07918044, -0.037572])

    R = np.eye(3)

    coord_homog = np.array([x, y, 1.0], dtype=np.float32).reshape(-1, 1)
    undistorted_coord = cv2.fisheye.undistortPoints(
        coord_homog.T[:, :2].reshape(1, -1, 2),
        K=K, D=D, R=R, P=P
    )[0][0]
    x_1, y_1 = undistorted_coord

    return x_1, y_1

# %%
def optical_flow(video_path, start_time, end_time, center_width, center_height, output_path, min_track_percent=100):
    cap = cv.VideoCapture(video_path)
    fps = cap.get(cv.CAP_PROP_FPS)
    #print('fps: ', fps)
    start_frame = int(start_time * fps)
    end_frame = int(end_time * fps)
    total_frames = end_frame - start_frame
    print('total_frames: ', total_frames)

    feature_params = dict(maxCorners=100, qualityLevel=0.3, minDistance=7, blockSize=7)
    lk_params = dict(winSize=(15, 15), maxLevel=2, criteria=(cv.TERM_CRITERIA_EPS | cv.TERM_CRITERIA_COUNT, 10, 0.03))
    color = np.random.randint(0, 255, (100, 3))

    cap.set(cv.CAP_PROP_POS_FRAMES, start_frame)
    ret, old_frame = cap.read()
    old_gray = cv.cvtColor(old_frame, cv.COLOR_BGR2GRAY)

    H, W = old_gray.shape[:2]

    h, w = old_gray.shape
    center_x, center_y = w // 2, h // 2
    half_width, half_height = center_width // 2, center_height // 2
    center_region = (slice(center_y - half_height, center_y + half_height), slice(center_x - half_width, center_x + half_width))
    p0 = cv.goodFeaturesToTrack(old_gray[center_region], mask=None, **feature_params)

    if p0 is not None:
        p0[:, :, 0] += center_x - half_width
        p0[:, :, 1] += center_y - half_height

    mask = np.zeros_like(old_frame)
    color_tracks = {}
    distance_tracker = {}

    fourcc = cv.VideoWriter_fourcc(*'XVID')
    out = cv.VideoWriter(output_path, fourcc, fps, (w, h))

    while True:
        ret, frame = cap.read()
        if not ret or cap.get(cv.CAP_PROP_POS_FRAMES) > end_frame:
            print('No frames grabbed!')
            break

        frame_gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)

        p1, st, err = cv.calcOpticalFlowPyrLK(old_gray, frame_gray, p0, None, **lk_params)

        if p1 is not None:
            good_new = p1[st == 1]
            good_old = p0[st == 1]

            for i, (new, old) in enumerate(zip(good_new, good_old)):
                a, b = new.ravel()
                c, d = old.ravel()
                point_id = tuple(map(int, old.ravel())) # store original point location

                distance = np.sqrt((a - c) ** 2 + (b - d) ** 2)

                mask = cv.line(mask, (int(a), int(b)), (int(c), int(d)), color[i % 100].tolist(), 2)
                frame = cv.circle(frame, (int(a), int(b)), 5, color[i % 100].tolist(), -1)
                color_used = tuple(color[i % 100].tolist())

                if color_used not in color_tracks:
                  color_tracks[color_used] = [(int(a), int(b)), (int(c), int(d))]
                  distance_tracker[color_used] = distance
                else:
                  color_tracks[color_used].append((int(c), int(d)))
                  distance_tracker[color_used] += distance

            img = cv.add(frame, mask)
            out.write(img)

        old_gray = frame_gray.copy()
        p0 = good_new.reshape(-1, 1, 2)

    cap.release()
    out.release()

    color_tracks_df = pd.DataFrame(list(color_tracks.items()), columns=['Color', 'Pixel_Positions'])
    color_tracks_df['Track_Length_Frame_Count'] = color_tracks_df['Pixel_Positions'].apply(len)
    color_tracks_df['Track_Percent'] = color_tracks_df['Track_Length_Frame_Count'] / total_frames * 100
    color_tracks_df = color_tracks_df[color_tracks_df['Track_Percent'] >= min_track_percent]

    distance_df = pd.DataFrame(list(distance_tracker.items()), columns=['Color', 'Connect_Dot_Distance'])
    color_tracks_df = pd.merge(color_tracks_df, distance_df, on='Color', how='left')
    color_tracks_df['Travel_Time_Seconds'] = color_tracks_df['Track_Length_Frame_Count'] / fps

    try:
      color_tracks_df['Total_Distance'] = color_tracks_df['Pixel_Positions'].apply(lambda x: np.sqrt((x[0][0] - x[-1][0]) ** 2 + (x[0][1] - x[-1][1]) ** 2))
      color_tracks_df['Corrected_Start_Pixel'] = color_tracks_df['Pixel_Positions'].apply(lambda x: get_undistorted_endpoints(x[0][0], x[0][1], H, W, mu=mu, S=S))
      color_tracks_df['Corrected_End_Pixel'] = color_tracks_df['Pixel_Positions'].apply(lambda x: get_undistorted_endpoints(x[-1][0], x[-1][1], H, W, mu=mu, S=S))
      color_tracks_df['X_Distance'] = color_tracks_df.apply(lambda row: np.sqrt((row['Corrected_Start_Pixel'][0] - row['Corrected_End_Pixel'][0]) ** 2), axis=1)
      color_tracks_df['Y_Distance'] = color_tracks_df.apply(lambda row: np.sqrt((row['Corrected_Start_Pixel'][1] - row['Corrected_End_Pixel'][1]) ** 2), axis=1)
      # color_tracks_df['X_Distance'] = color_tracks_df['Pixel_Positions'].apply(lambda x: (x[-1][0] - x[0][0]))
      # color_tracks_df['Y_Distance'] = color_tracks_df['Pixel_Positions'].apply(lambda x: (x[-1][1] - x[0][1]))
      # color_tracks_df['Overall_Velocity'] = color_tracks_df['Total_Distance'] / color_tracks_df['Travel_Time_Seconds']
      color_tracks_df['X_Velocity'] = color_tracks_df['X_Distance'] / color_tracks_df['Travel_Time_Seconds']
      color_tracks_df['Y_Velocity'] = color_tracks_df['Y_Distance'] / color_tracks_df['Travel_Time_Seconds']
    except:
      print("none able to be tracked")

    return color_tracks_df

# Example usage:
# df = optical_flow('video.mp4', 10, 20, 12, 12, 'output.avi', min_track_percent=80)
# print(df)

# %%
import time
result_df = None

curr_timestr = time.strftime("%Y%m%d_%H%M%S")

for index, row in truth_df.iterrows():
    frame_number = row['frame_num']
    print("Frame Number: ", frame_number)
    start_time = row['time_since_first_frame']
    end_time = start_time + 10
    center_width = 48
    center_height = 48
    v = row['Grnd_Spd']
    h = row['GPS_MSL_Alt']
    pitch = row['Pitch']
    try:
      df = optical_flow('/content/drive/MyDrive/NASA/input_videos/full_videos/170418_175706_183328.avi', start_time=start_time, end_time=end_time, center_width=center_width, center_height=center_height, output_path=f'/content/drive/MyDrive/NASA/output/frame_tracking_fisheye_corrected_48_48/cloud_tracking_{frame_number}.mp4')
      df = calculate_cloud_height(df, v, h, pitch, f=1.4, diam=8, frame_pixels=1080)
      df['Frame_Number'] = frame_number
      df['True_Lidar_Height'] = row['top_height']
      #df.to_csv(f'/content/drive/MyDrive/NASA/output/dataframes/cloud_tracking_{frame_number}.csv', index=False)
      if result_df is None:
        result_df = df
      else:
        result_df = pd.concat([result_df, df])
      print("Avg Tracked Pixels Height: ", df[['Height']].mean())
      print("True Lidar Height: ", row['top_height'])
    except Exception as e:
      print(e)
      print("No tracking")
# Out:
# Frame Number:  180
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12571.677467
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  480
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12150.919093
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  780
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12268.455246
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  1080
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12375.560931
# dtype: float64
# True Lidar Height:  13191.0
# Frame Number:  1380
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12402.799439
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  1680
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12055.95788
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  1980
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13214.153077
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  2280
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12914.842612
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  2580
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12662.022464
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  2880
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12960.105605
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  3180
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12898.911195
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  3480
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12507.334015
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  3780
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12673.644316
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  4080
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12582.733465
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  4380
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12822.500732
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  4680
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12757.495902
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  4980
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13495.135372
# dtype: float64
# True Lidar Height:  13191.0
# Frame Number:  5280
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11849.71428
# dtype: float64
# True Lidar Height:  13221.0
# Frame Number:  5580
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11979.64533
# dtype: float64
# True Lidar Height:  13221.0
# Frame Number:  5880
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12393.515785
# dtype: float64
# True Lidar Height:  13191.0
# Frame Number:  6180
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12655.388961
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  6480
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12428.404942
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  6780
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12639.546799
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  7080
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12683.751529
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  7380
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12488.475509
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  7680
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12689.840165
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  7980
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  8280
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12204.255181
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  8580
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12312.356896
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  8880
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12074.841164
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  9180
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12186.659562
# dtype: float64
# True Lidar Height:  13251.0
# Frame Number:  9480
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  9780
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12346.727034
# dtype: float64
# True Lidar Height:  13251.0
# Frame Number:  10080
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  10380
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  10680
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  10980
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12863.16314
# dtype: float64
# True Lidar Height:  13281.0
# Frame Number:  11280
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13101.869593
# dtype: float64
# True Lidar Height:  13281.0
# Frame Number:  11580
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12187.326958
# dtype: float64
# True Lidar Height:  13281.0
# Frame Number:  11880
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12144.13802
# dtype: float64
# True Lidar Height:  13281.0
# Frame Number:  12180
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13351.941841
# dtype: float64
# True Lidar Height:  13281.0
# Frame Number:  12480
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  12780
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  13080
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  13380
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  13680
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  13980
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13516.456171
# dtype: float64
# True Lidar Height:  13221.0
# Frame Number:  14280
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13305.001655
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  14580
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13463.206144
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  14880
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12671.190283
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  15180
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12234.557641
# dtype: float64
# True Lidar Height:  13191.0
# Frame Number:  15480
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12166.200534
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  15780
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12697.287595
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  16080
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12636.249485
# dtype: float64
# True Lidar Height:  13041.0
# Frame Number:  16380
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12920.024892
# dtype: float64
# True Lidar Height:  13041.0
# Frame Number:  16680
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12969.847964
# dtype: float64
# True Lidar Height:  13041.0
# Frame Number:  16980
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13015.146371
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  17280
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12831.850936
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  17580
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12820.156968
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  17880
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12269.332961
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  18180
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12955.100788
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  18480
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12605.285418
# dtype: float64
# True Lidar Height:  13041.0
# Frame Number:  18780
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12555.271813
# dtype: float64
# True Lidar Height:  13041.0
# Frame Number:  19080
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12319.005411
# dtype: float64
# True Lidar Height:  13041.0
# Frame Number:  19380
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12444.428045
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  19740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12688.188312
# dtype: float64
# True Lidar Height:  13041.0
# Frame Number:  20040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13255.934636
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  20340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11707.419005
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  20640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12031.720684
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  20940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11999.23976
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  21240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11765.566422
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  21540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  21840
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  22140
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  22440
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  22740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  23040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  23340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  23640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  23940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    6473.532077
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  24240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12921.799604
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  24540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12422.852464
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  24840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11293.911056
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  25140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13537.752607
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  25440
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  25740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  26040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  26340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  26640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  26940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  27240
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  27540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  27840
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  28140
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  28440
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  28740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  29040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  29340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  29640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  29940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  30240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  30540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  30840
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  31140
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  31440
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  31740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  32040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    235.422969
# dtype: float64
# True Lidar Height:  13011.0
# Frame Number:  32340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12730.958331
# dtype: float64
# True Lidar Height:  13011.0
# Frame Number:  32640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  32940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  33240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  33840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14772.856023
# dtype: float64
# True Lidar Height:  12861.0
# Frame Number:  34140
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  34440
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  34740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  35040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  35340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  35640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    9180.987131
# dtype: float64
# True Lidar Height:  12891.0
# Frame Number:  35940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  36240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12661.572457
# dtype: float64
# True Lidar Height:  12891.0
# Frame Number:  36540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  36840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14214.445351
# dtype: float64
# True Lidar Height:  12861.0
# Frame Number:  37140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    8795.43739
# dtype: float64
# True Lidar Height:  12891.0
# Frame Number:  37440
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  37740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  38040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  38340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  38640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  38940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  39240
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  39540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  39840
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  40140
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  40440
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  40740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  41040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  41340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  41640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  41940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  42240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  42540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  42840
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  43140
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  43440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12173.753972
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  43740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11905.331733
# dtype: float64
# True Lidar Height:  13041.0
# Frame Number:  44040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  44340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  44640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  44940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  45240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  45540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  45840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    10803.788349
# dtype: float64
# True Lidar Height:  13011.0
# Frame Number:  46140
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  46440
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  46740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  47040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  47340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  47640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  47940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  48240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  48540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  48840
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  49140
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  49440
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  49740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  50040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  50340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  50640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  50940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  51240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  51840
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  52140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    7452.383799
# dtype: float64
# True Lidar Height:  12831.0
# Frame Number:  52440
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  52740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  53040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  53340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    15007.085833
# dtype: float64
# True Lidar Height:  12861.0
# Frame Number:  53640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    16162.879066
# dtype: float64
# True Lidar Height:  12861.0
# Frame Number:  53940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  54240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  54540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  54840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    15586.602772
# dtype: float64
# True Lidar Height:  12951.0
# Frame Number:  55140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    15506.055202
# dtype: float64
# True Lidar Height:  12951.0
# Frame Number:  55440
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  55740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  56040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  56640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  56940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  57240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  57540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  57840
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  58140
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  58440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12822.896625
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  58740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11092.554022
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  59040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  59340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  59640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13425.25981
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  59940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13347.672368
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  60240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12473.989411
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  60540
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  60840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    6583.915297
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  61140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12811.147163
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  61440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13262.263821
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  61740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13210.783378
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  62040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13116.857382
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  62340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13414.996673
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  62640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13445.983668
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  62940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12637.515348
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  63240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12987.823124
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  63540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12701.597419
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  63840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12985.50908
# dtype: float64
# True Lidar Height:  13101.0
# Frame Number:  64140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13117.4874
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  64440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11945.725322
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  64740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12897.814135
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  65040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13651.837463
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  65340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    8683.35523
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  65640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  65940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    3330.612867
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  66240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    8531.537465
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  66540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12170.851593
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  66840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12306.609441
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  67140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12706.907951
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  67440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13046.698837
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  67740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13331.488017
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  68040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13085.821015
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  68340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12962.848906
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  68640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12708.115873
# dtype: float64
# True Lidar Height:  13341.0
# Frame Number:  68940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12942.802226
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  69240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12772.080184
# dtype: float64
# True Lidar Height:  13131.0
# Frame Number:  69540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13309.363183
# dtype: float64
# True Lidar Height:  13191.0
# Frame Number:  69840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    10621.438046
# dtype: float64
# True Lidar Height:  13191.0
# Frame Number:  70140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    9564.22145
# dtype: float64
# True Lidar Height:  13221.0
# Frame Number:  70440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13476.640434
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  70740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  71040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14327.828814
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  71340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  71640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13189.811807
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  71940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11831.513137
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  72240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12705.693625
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  72540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12986.040631
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  72840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13168.292815
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  73140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12903.40275
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  73440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13055.382993
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  73740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12890.079341
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  74040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12564.756272
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  74340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12953.090248
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  74640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12902.742981
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  74940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12234.627082
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  75240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13025.529186
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  75540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13475.242671
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  75840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13074.718221
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  76140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13058.355262
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  76440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12546.280612
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  76740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12793.17618
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  77040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13209.675406
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  77340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13134.073624
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  77640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13219.674918
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  77940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12919.597065
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  78240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13075.451747
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  78540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12866.83145
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  78840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12711.925888
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  79140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12523.898433
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  79440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13251.818805
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  79740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13299.300018
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  80040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13075.99226
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  80340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13004.16319
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  80640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13005.929829
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  80940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13236.844148
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  81240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13480.348094
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  81540
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  81840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13319.466539
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  82140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13437.183906
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  82440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12974.607235
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  82740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12869.314937
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  83040
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  83340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12600.003333
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  83640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12136.753069
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  83940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  84240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13743.108511
# dtype: float64
# True Lidar Height:  13281.0
# Frame Number:  84540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13738.788503
# dtype: float64
# True Lidar Height:  13221.0
# Frame Number:  84840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13125.199704
# dtype: float64
# True Lidar Height:  13191.0
# Frame Number:  85140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12963.844566
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  85440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13287.18946
# dtype: float64
# True Lidar Height:  13161.0
# Frame Number:  85740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13384.090943
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  86040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11433.310605
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  86340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  86640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14750.869902
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  86940
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  87240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12866.39299
# dtype: float64
# True Lidar Height:  13041.0
# Frame Number:  87540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13720.219898
# dtype: float64
# True Lidar Height:  12981.0
# Frame Number:  87840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13310.767608
# dtype: float64
# True Lidar Height:  12951.0
# Frame Number:  88140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    10718.849769
# dtype: float64
# True Lidar Height:  12921.0
# Frame Number:  88440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11621.290777
# dtype: float64
# True Lidar Height:  12921.0
# Frame Number:  88740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  89040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14694.389304
# dtype: float64
# True Lidar Height:  12981.0
# Frame Number:  89340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12201.47777
# dtype: float64
# True Lidar Height:  13011.0
# Frame Number:  89640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13172.366089
# dtype: float64
# True Lidar Height:  12981.0
# Frame Number:  89940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12817.355451
# dtype: float64
# True Lidar Height:  12951.0
# Frame Number:  90240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13344.090522
# dtype: float64
# True Lidar Height:  12951.0
# Frame Number:  90540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11135.912112
# dtype: float64
# True Lidar Height:  12921.0
# Frame Number:  90840
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  91140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    8474.86491
# dtype: float64
# True Lidar Height:  12951.0
# Frame Number:  91440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    10697.425211
# dtype: float64
# True Lidar Height:  12951.0
# Frame Number:  91740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height   -4615.933369
# dtype: float64
# True Lidar Height:  12951.0
# Frame Number:  92040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  92340
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  92640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    5387.538535
# dtype: float64
# True Lidar Height:  13071.0
# Frame Number:  92940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13427.434004
# dtype: float64
# True Lidar Height:  13041.0
# Frame Number:  93240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  93540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    6871.577679
# dtype: float64
# True Lidar Height:  13011.0
# Frame Number:  93840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12790.066165
# dtype: float64
# True Lidar Height:  13611.0
# Frame Number:  94140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height   -29459.87163
# dtype: float64
# True Lidar Height:  12981.0
# Frame Number:  94440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12762.345038
# dtype: float64
# True Lidar Height:  12981.0
# Frame Number:  94740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  95040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11495.160964
# dtype: float64
# True Lidar Height:  13611.0
# Frame Number:  95340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13516.935262
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  95640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12032.051714
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  95940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13045.1584
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  96240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    7206.945282
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  96540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    8349.947597
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  96840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13199.246492
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  97140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13017.38335
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  97440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13699.71987
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  97740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11381.305601
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  98040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12238.124644
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  98340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13084.43278
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  98640
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  98940
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  99240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  99540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11047.191397
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  99840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    11486.975349
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  100140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13154.431132
# dtype: float64
# True Lidar Height:  13701.0
# Frame Number:  100440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13375.830053
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  100740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13697.315387
# dtype: float64
# True Lidar Height:  13701.0
# Frame Number:  101040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13548.841049
# dtype: float64
# True Lidar Height:  13701.0
# Frame Number:  101340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13366.820664
# dtype: float64
# True Lidar Height:  13701.0
# Frame Number:  101640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13607.436094
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  101940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13897.189975
# dtype: float64
# True Lidar Height:  13701.0
# Frame Number:  102240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13489.403823
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  102540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13539.298524
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  102840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13668.80157
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  103140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13566.171611
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  103440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13769.46785
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  103740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13780.542966
# dtype: float64
# True Lidar Height:  13611.0
# Frame Number:  104040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13612.416662
# dtype: float64
# True Lidar Height:  13551.0
# Frame Number:  104340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13428.085914
# dtype: float64
# True Lidar Height:  13491.0
# Frame Number:  104640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13560.967125
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  104940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13687.693682
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  105240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13672.286286
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  105540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  105840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13089.119732
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  106140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13474.402819
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  106440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13778.857377
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  106740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  107040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13556.870224
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  107340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13478.562064
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  107640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13541.339775
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  107940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13293.594594
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  108240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13657.542443
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  108540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13723.156105
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  108840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13963.431017
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  109140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13651.552919
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  109440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13671.056776
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  109740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13629.360624
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  110040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13830.773673
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  110340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12650.039069
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  110640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13613.351641
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  110940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13943.894129
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  111240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13617.150772
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  111540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13228.94896
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  111840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13732.982391
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  112140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13503.824551
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  112440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13478.467531
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  112740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13695.565847
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  113040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13885.221432
# dtype: float64
# True Lidar Height:  13431.0
# Frame Number:  113340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13849.548336
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  113640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13879.135686
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  113940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13859.546631
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  114240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13921.962982
# dtype: float64
# True Lidar Height:  13401.0
# Frame Number:  114540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13847.268732
# dtype: float64
# True Lidar Height:  13461.0
# Frame Number:  114840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13582.363007
# dtype: float64
# True Lidar Height:  13521.0
# Frame Number:  115140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13651.239658
# dtype: float64
# True Lidar Height:  13581.0
# Frame Number:  115440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13443.16927
# dtype: float64
# True Lidar Height:  13611.0
# Frame Number:  115740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14708.206473
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  116040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    15670.732356
# dtype: float64
# True Lidar Height:  13611.0
# Frame Number:  116640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    16044.907098
# dtype: float64
# True Lidar Height:  13551.0
# Frame Number:  116940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    15503.398888
# dtype: float64
# True Lidar Height:  13581.0
# Frame Number:  117240
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  117540
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  117840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14503.525498
# dtype: float64
# True Lidar Height:  13491.0
# Frame Number:  118140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    15419.39938
# dtype: float64
# True Lidar Height:  13551.0
# Frame Number:  118440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    16090.33535
# dtype: float64
# True Lidar Height:  13521.0
# Frame Number:  118740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    15916.980178
# dtype: float64
# True Lidar Height:  13551.0
# Frame Number:  119040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    15675.359263
# dtype: float64
# True Lidar Height:  13551.0
# Frame Number:  119340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    15405.277563
# dtype: float64
# True Lidar Height:  13551.0
# Frame Number:  119640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13166.340073
# dtype: float64
# True Lidar Height:  13371.0
# Frame Number:  119940
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  120240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14621.673717
# dtype: float64
# True Lidar Height:  13191.0
# Frame Number:  120540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14771.122769
# dtype: float64
# True Lidar Height:  13281.0
# Frame Number:  120840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    17004.900634
# dtype: float64
# True Lidar Height:  13311.0
# Frame Number:  121440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12504.637981
# dtype: float64
# True Lidar Height:  13521.0
# Frame Number:  121740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12299.79141
# dtype: float64
# True Lidar Height:  12262.0
# Frame Number:  122040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14256.596097
# dtype: float64
# True Lidar Height:  13521.0
# Frame Number:  122340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    14491.684055
# dtype: float64
# True Lidar Height:  13551.0
# Frame Number:  122640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13602.776224
# dtype: float64
# True Lidar Height:  13551.0
# Frame Number:  122940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13175.519708
# dtype: float64
# True Lidar Height:  13521.0
# Frame Number:  123240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12887.468229
# dtype: float64
# True Lidar Height:  13611.0
# Frame Number:  123540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12966.947014
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  123840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13476.513324
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  124140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13690.108753
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  124440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13506.498493
# dtype: float64
# True Lidar Height:  11962.0
# Frame Number:  124740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13121.465116
# dtype: float64
# True Lidar Height:  13641.0
# Frame Number:  125040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13311.20857
# dtype: float64
# True Lidar Height:  13671.0
# Frame Number:  125340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13295.555885
# dtype: float64
# True Lidar Height:  12052.0
# Frame Number:  125640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13314.239012
# dtype: float64
# True Lidar Height:  11932.0
# Frame Number:  125940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13095.574041
# dtype: float64
# True Lidar Height:  11932.0
# Frame Number:  126240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13144.164592
# dtype: float64
# True Lidar Height:  11992.0
# Frame Number:  126540
# total_frames:  600
# OpenCV(4.10.0-dev) /content/opencv/modules/video/src/lkpyramid.cpp:1281: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, CV_32F, true)) >= 0 in function 'calc'
#
# No tracking
# Frame Number:  126840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13589.154285
# dtype: float64
# True Lidar Height:  12052.0
# Frame Number:  127140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13558.018205
# dtype: float64
# True Lidar Height:  12052.0
# Frame Number:  127440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13185.897875
# dtype: float64
# True Lidar Height:  12082.0
# Frame Number:  127740
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13317.460271
# dtype: float64
# True Lidar Height:  12382.0
# Frame Number:  128040
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13064.036133
# dtype: float64
# True Lidar Height:  12382.0
# Frame Number:  128340
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12960.082831
# dtype: float64
# True Lidar Height:  12382.0
# Frame Number:  128640
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    12929.128446
# dtype: float64
# True Lidar Height:  12382.0
# Frame Number:  128940
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13218.582828
# dtype: float64
# True Lidar Height:  12442.0
# Frame Number:  129240
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13326.610948
# dtype: float64
# True Lidar Height:  12472.0
# Frame Number:  129540
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13841.378154
# dtype: float64
# True Lidar Height:  12382.0
# Frame Number:  129840
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13168.507686
# dtype: float64
# True Lidar Height:  11962.0
# Frame Number:  130140
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13199.591131
# dtype: float64
# True Lidar Height:  12022.0
# Frame Number:  130440
# total_frames:  600
# No frames grabbed!
# Avg Tracked Pixels Height:  Height    13546.881535
# dtype: float64
# True Lidar Height:  12082.0
# Frame Number:  130740
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking
# Frame Number:  131040
# total_frames:  600
# No frames grabbed!
# none able to be tracked
# 'X_Velocity'
# No tracking

# %%
# save calculated LK-based heights for test video
result_df.to_csv(f'/content/drive/MyDrive/NASA/output/dataframes/{curr_timestr}_LK_output_48_48_fisheye_corrected.csv', index=False)

# %%
result_df.shape
# Out:
# (1333, 18)

# %%
result_df.Frame_Number.nunique()
# Out:
# 294

# %%
truth_df.frame_num.nunique()
# Out:
# 432

# %%
# read latest saved heights csv from this current run
df = pd.read_csv(f'/content/drive/MyDrive/NASA/output/dataframes/{curr_timestr}_LK_output_48_48_fisheye_corrected.csv')
df.head()
# Out:
#              Color                                    Pixel_Positions  \
# 0     (15, 3, 152)  [(955, 547), (956, 547), (955, 547), (955, 547...
# 1   (78, 124, 171)  [(942, 524), (942, 524), (942, 524), (942, 524...
# 2  (177, 215, 114)  [(962, 550), (963, 550), (962, 550), (963, 550...
# 3   (18, 254, 161)  [(967, 522), (968, 523), (967, 522), (968, 522...
# 4   (154, 93, 100)  [(971, 530), (971, 530), (971, 530), (971, 530...
#
#    Track_Length_Frame_Count  Track_Percent  Connect_Dot_Distance  \
# 0                       600          100.0            108.239769
# 1                       600          100.0            119.434668
# 2                       600          100.0            107.023602
# 3                       600          100.0            104.666403
# 4                       600          100.0            101.307727
#
#    Travel_Time_Seconds  Total_Distance   Corrected_Start_Pixel  \
# 0                 10.0       49.040799  (1914.9972, 1087.0046)
# 1                 10.0       63.126856   (1901.922, 1063.9309)
# 2                 10.0       46.173586  (1922.0023, 1090.0099)
# 3                 10.0       51.156622  (1927.0221, 1061.9484)
# 4                 10.0       50.358713  (1931.0208, 1069.9828)
#
#       Corrected_End_Pixel  X_Distance  Y_Distance  X_Velocity  Y_Velocity  \
# 0   (1912.8224, 1137.544)    2.174805   50.539307    0.217480    5.053931
# 1  (1897.5095, 1128.0836)    4.412476   64.152710    0.441248    6.415271
# 2   (1917.9596, 1137.524)    4.042725   47.514160    0.404272    4.751416
# 3   (1931.1188, 1113.346)    4.096680   51.397583    0.409668    5.139758
# 4   (1937.283, 1120.6549)    6.262207   50.672119    0.626221    5.067212
#
#    X_Velocity_Converted  Y_Velocity_Converted        Height  Frame_Number  \
# 0              0.001611              0.037437  12383.638140           180
# 1              0.003269              0.047521  13992.744310           180
# 2              0.002995              0.035196  11900.850273           180
# 3              0.003035              0.038072  12510.262555           180
# 4              0.004639              0.037535  12403.512945           180
#
#    True_Lidar_Height
# 0            13161.0
# 1            13161.0
# 2            13161.0
# 3            13161.0
# 4            13161.0

# %%
# Group by the 'Category' column
grouped = df.groupby('Frame_Number', as_index = False)

# Calculate multiple aggregations
result = grouped.agg({
    'Height': ['max', 'min', 'mean'],
    'True_Lidar_Height': 'mean'
})

# results_df['mean_center_height'] = results_df.groupby('Frame_Number', as_index = False)['Height'].mean().Height
# results_df['max_center_height'] = results_df.groupby('Frame_Number', as_index = False)['Height'].max().Height
# results_df['min_center_height'] = results_df.groupby('Frame_Number', as_index = False)['Height'].min().Height
# save max, mean, min heights column if not already existing
#results_df.to_csv('/content/drive/MyDrive/NASA/output/dataframes/20241027_051119_LK_output.csv', index=False)
print(result.shape)

result.head()
result.to_csv(f'/content/drive/MyDrive/NASA/output/dataframes/{curr_timestr}_LK_output_height_min_max_mean_48_48_fisheye_corrected.csv', index=False)
# Out:
# (294, 5)
